# %% [markdown]
# <a href="https://colab.research.google.com/github/pietroavansi/Exercicios-Saulo/blob/main/aula3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idade = int(input('Idade:'))
altura = float(input('Altura:'))
acompanhado = True

if (altura >= 1.50 and idade > 12):
  print('liberado')

elif (altura >= 1.30 and acompanhado):
  print('liberado')

else:
  print('bloqueado')
