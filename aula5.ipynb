# %% [markdown]
# <a href="https://colab.research.google.com/github/pietroavansi/Exercicios-Saulo/blob/main/aula5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
contador = 10
print("Vai começar a contagem!")
while contador >= 1:
    print(f"{contador}")
    contador = (contador - 1)

print("BUM!")
