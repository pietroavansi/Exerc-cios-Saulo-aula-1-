# %% [markdown]
# <a href="https://colab.research.google.com/github/pietroavansi/Exerc-cios-Saulo-aula-1-/blob/main/Exerc%C3%ADcios_aula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
seu_peso = float(input('Digite seu peso em kg:'))
altura = float(input('Digite sua altura em metros:'))
a = 2
IMC = seu_peso/altura**a
IMC = round(IMC,2)
print(f'{IMC}')
